# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
#Create Data path 
path = r'C:\Users\Neway\OneDrive\Desktop\instacart Basket Analysis'

# %%
#import data csv's
#orders data
df_ords = pd.read_csv(os.path.join(path, '02 Data', 'Original data', 'orders.csv'), index_col = False)
#products data
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Original data', 'products.csv'), index_col = False)
#departments data
df_dep = pd.read_csv(os.path.join(path, '02 Data', 'Original data', 'departments.csv'), index_col = False)

# %% [markdown]
# # COPY OF WRINGLED data as per exercise

# %%
# drop eval set column from orders.csv
df_ords=df_ords.drop(columns=['eval_set'])

# %%
df_ords.head()
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1             1          2                  8
# 1   2398795        1             2          3                  7
# 2    473747        1             3          3                 12
# 3   2254736        1             4          4                  7
# 4    431534        1             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
df_ords['order_id'] = df_ords['order_id'].astype('str')
df_ords['user_id'] = df_ords['user_id'].astype('str')

# %%
df_dep_t = df_dep.T
df_dep_t = df_dep_t.reset_index()
new_header = df_dep_t.iloc[0]
df_dep_t_new = df_dep_t[1:]
df_dep_t_new.columns = new_header

df_dep_t_new
data_dict = df_dep_t_new.to_dict('index')
print(data_dict.get('4'))
# Out:
# None

# %%
df_breakfast = df_prods[df_prods['department_id']==14]
df_breakfast.head()
# Out:
#      product_id                                      product_name  aisle_id  \
# 27           28                                 Wheat Chex Cereal       121
# 33           34                                               NaN       121
# 67           68                           Pancake Mix, Buttermilk       130
# 89           90                                      Smorz Cereal       121
# 210         211  Gluten Free Organic Cereal Coconut Maple Vanilla       130
#
#      department_id  prices
# 27              14    10.1
# 33              14    12.2
# 67              14    13.7
# 89              14     3.9
# 210             14     3.6

# %% [markdown]
# Task

# %%
df_ords.head()
# Out:
#   order_id user_id  order_number  order_dow  order_hour_of_day  \
# 0  2539329       1             1          2                  8
# 1  2398795       1             2          3                  7
# 2   473747       1             3          3                 12
# 3  2254736       1             4          4                  7
# 4   431534       1             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %% [markdown]
# No math or statistacal calcualtions will be done on order_id, will be only be used as primary/foreign key

# %%
df_ords['order_number'] = df_ords['order_number'].astype('str')

# %%
df_ords.dtypes
# Out:
# order_id                   object
# user_id                    object
# order_number               object
# order_dow                   int64
# order_hour_of_day           int64
# days_since_prior_order    float64
# dtype: object

# %% [markdown]
# order_dow can be changed to ordersz-day_of_week, just as order_hour_or_day is used

# %%
df_ords.rename(columns = {'order_dow' : 'orders_day_of_week'}, inplace = True)

# %%
df_ords.head()
# Out:
#   order_id user_id order_number  orders_day_of_week  order_hour_of_day  \
# 0  2539329       1            1                   2                  8
# 1  2398795       1            2                   3                  7
# 2   473747       1            3                   3                 12
# 3  2254736       1            4                   4                  7
# 4   431534       1            5                   4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %% [markdown]
# 4.

# %%
df_ords['order_hour_of_day'].value_counts(dropna = True)
# Out:
# order_hour_of_day
# 10    288418
# 11    284728
# 15    283639
# 14    283042
# 13    277999
# 12    272841
# 16    272553
# 9     257812
# 17    228795
# 18    182912
# 8     178201
# 19    140569
# 20    104292
# 7      91868
# 21     78109
# 22     61468
# 23     40043
# 6      30529
# 0      22758
# 1      12398
# 5       9569
# 2       7539
# 4       5527
# 3       5474
# Name: count, dtype: int64

# %% [markdown]
# 10:00 is the busiest hour for placing orders

# %% [markdown]
# #5

# %%
df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
print(data_dict.get('4'))
# Out:
# None

# %%
{'department': 'produce'}
# Out:
# {'department': 'produce'}

# %% [markdown]
# 4 mean produce

# %% [markdown]
# 6

# %%
data_dict
# Out:
# {1: {'order_id': 'user_id',
#   2539329: 1,
#   2398795: 1,
#   473747: 1,
#   2254736: 1,
#   431534: 1,
#   3367565: 1,
#   550135: 1,
#   3108588: 1,
#   2295261: 1,
#   2550362: 1,
#   1187899: 1,
#   2168274: 2,
#   1501582: 2,
#   1901567: 2,
#   738281: 2,
#   1673511: 2,
#   1199898: 2,
#   3194192: 2,
#   788338: 2,
#   1718559: 2,
#   1447487: 2,
#   1402090: 2,
#   3186735: 2,
#   3268552: 2,
#   839880: 2,
#   1492625: 2,
#   1374495: 3,
#   444309: 3,
#   3002854: 3,
#   2037211: 3,
#   2710558: 3,
#   1972919: 3,
#   1839752: 3,
#   3225766: 3,
#   3160850: 3,
#   676467: 3,
#   521107: 3,
#   1402502: 3,
#   2774568: 3,
#   3343014: 4,
#   2030307: 4,
#   691089: 4,
#   94891: 4,
#   2557754: 4,
#   329954: 4,
#   2717275: 5,
#   1909121: 5,
#   2267326: 5,
#   157374: 5,
#   2196797: 5,
#   2086598: 6,
#   298250: 6,
#   998866: 6,
#   1528013: 6,
#   2565571: 7,
#   2402008: 7,
#   121053: 7,
#   1695742: 7,
#   3321109: 7,
#   1682003: 7,
#   1014379: 7,
# ...

# %%
# create subset for breakfast
df_prods_breakfast = df_prods.loc[df_prods['department_id'] == 14]

# %%
df_prods_breakfast.head()
# Out:
#      product_id                                      product_name  aisle_id  \
# 27           28                                 Wheat Chex Cereal       121
# 33           34                                               NaN       121
# 67           68                           Pancake Mix, Buttermilk       130
# 89           90                                      Smorz Cereal       121
# 210         211  Gluten Free Organic Cereal Coconut Maple Vanilla       130
#
#      department_id  prices
# 27              14    10.1
# 33              14    12.2
# 67              14    13.7
# 89              14     3.9
# 210             14     3.6

# %% [markdown]
# 7.

# %%
#create subset for dinner party
df_prods_dinner_party = df_prods.loc[df_prods['department_id'].isin([5,7,12,20])]

# %%
df_prods_dinner_party.head()
# Out:
#     product_id                                    product_name  aisle_id  \
# 2            3            Robust Golden Unsweetened Oolong Tea        94
# 6            7                  Pure Coconut Water With Orange        98
# 9           10  Sparkling Orange Juice & Prickly Pear Beverage       115
# 10          11                               Peach Mango Juice        31
# 16          17                               Rendered Duck Fat        35
#
#     department_id  prices
# 2               7     4.5
# 6               7     4.4
# 9               7     8.4
# 10              7     2.8
# 16             12    17.1

# %%
df_prods_dinner_party.shape
# Out:
# (7650, 5)

# %% [markdown]
# 9.

# %%
# set a data frame for user_id 1
df_user1=df_ords.loc[df_ords['user_id'] == '1']

# %%
df_user1
# Out:
#    order_id user_id order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329       1            1                   2                  8
# 1   2398795       1            2                   3                  7
# 2    473747       1            3                   3                 12
# 3   2254736       1            4                   4                  7
# 4    431534       1            5                   4                 15
# 5   3367565       1            6                   2                  7
# 6    550135       1            7                   1                  9
# 7   3108588       1            8                   1                 14
# 8   2295261       1            9                   1                 16
# 9   2550362       1           10                   4                  8
# 10  1187899       1           11                   4                  8
#
#     days_since_prior_order
# 0                      NaN
# 1                     15.0
# ...

# %% [markdown]
# 10

# %%
df_user1.describe()
# Out:
#        orders_day_of_week  order_hour_of_day  days_since_prior_order
# count           11.000000          11.000000               10.000000
# mean             2.636364          10.090909               19.000000
# std              1.286291           3.477198                9.030811
# min              1.000000           7.000000                0.000000
# 25%              1.500000           7.500000               14.250000
# 50%              3.000000           8.000000               19.500000
# 75%              4.000000          13.000000               26.250000
# max              4.000000          16.000000               30.000000

# %% [markdown]
# This user place orders at the start of the week ,a dn usually will order before 12pm. The average mean time between placing orders is 19 days.

# %% [markdown]
# 12

# %%
df_ords.to_csv(os.path.join(path, '02 Data','Prepared Data', 'orders_wrangled.csv'))

# %% [markdown]
# 13

# %%
df_dep_t_new.to_csv(os.path.join(path, '02 Data','Prepared Data', 'departments_wrangled.csv'))
